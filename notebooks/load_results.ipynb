# %%
from sgd_complexity.pipelines import ExperimentPipeline
import yaml

# %%
with open('../experiments/demo-fast.yml') as f:
    config = yaml.safe_load(f)
demo_fast = ExperimentPipeline(config=config)
demo_fast.load_results(path="../results/demo-fast.pkl")

# %%
demo_fast.plot_results()
